# %%
import yfinance as yf
import pandas as pd
tickers = ["GOOGL", "AMZN"]
data = yf.download("GOOGL", start="2023-01-01", end="2024-12-31")
csv_formatted = pd.DataFrame.to_csv(data)
# Out:
# [*********************100%%**********************]  1 of 1 completed
# ...
